# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('winemag-data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.head(15)
# Out:
#     Unnamed: 0   country                                        description  \
# 0            0     Italy  Aromas include tropical fruit, broom, brimston...
# 1            1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2            2        US  Tart and snappy, the flavors of lime flesh and...
# 3            3        US  Pineapple rind, lemon pith and orange blossom ...
# 4            4        US  Much like the regular bottling from 2012, this...
# 5            5     Spain  Blackberry and raspberry aromas show a typical...
# 6            6     Italy  Here's a bright, informal red that opens with ...
# 7            7    France  This dry and restrained wine offers spice in p...
# 8            8   Germany  Savory dried thyme notes accent sunnier flavor...
# 9            9    France  This has great depth of flavor with its fresh ...
# 10          10        US  Soft, supple plum envelopes an oaky structure ...
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 country                                        description  \
# 77356       77356      US  Lightly pink in color with a hint of orange, t...
# 77357       77357  France  This wine is plump, rounded and rich. Ripe hin...
# 77358       77358   Italy  Underbrush, red berry and coffee bean lead the...
# 77359       77359  France  This is a concentrated wine—firm and structure...
# 77360       77360  France  A small portion of this producer's vineyard, p...
#
#            designation  points  price    province             region_1  \
# 77356  Gesture Rose of      87   18.0  California          Paso Robles
# 77357      Les Natures      87   25.0      Alsace               Alsace
# 77358              NaN      87   25.0     Tuscany  Rosso di Montalcino
# 77359              NaN      87   20.0  Beaujolais  Beaujolais-Villages
# 77360  Vieilles Vignes      87   20.0  Beaujolais  Beaujolais-Villages
#
#             region_2       taster_name taster_twitter_handle  \
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0   country  \
# 77351       77351        US
# 77352       77352     Italy
# 77353       77353        US
# 77354       77354    Greece
# 77355       77355  Portugal
# 77356       77356        US
# 77357       77357    France
# 77358       77358     Italy
# 77359       77359    France
# 77360       77360    France
#
#                                              description  \
# 77351  This wine is a blend of top sites Stoney Vine,...
# 77352  Red berry, rose and anise aromas mingle in the...
# 77353  The aromas of woodspice, vanilla and cedar are...
# 77354  On the nose, this exotic white offers banana, ...
# 77355  A ripe wine, full of red berry fruits contrast...
# 77356  Lightly pink in color with a hint of orange, t...
# 77357  This wine is plump, rounded and rich. Ripe hin...
# 77358  Underbrush, red berry and coffee bean lead the...
# 77359  This is a concentrated wine—firm and structure...
# 77360  A small portion of this producer's vineyard, p...
#
# ...

# %%
df.shape
# Out:
# (77361, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77361 entries, 0 to 77360
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             77361 non-null  int64
#  1   country                77326 non-null  object
#  2   description            77361 non-null  object
#  3   designation            55005 non-null  object
#  4   points                 77361 non-null  int64
#  5   price                  71903 non-null  float64
#  6   province               77326 non-null  object
#  7   region_1               64754 non-null  object
#  8   region_2               29741 non-null  object
#  9   taster_name            61544 non-null  object
#  10  taster_twitter_handle  58672 non-null  object
#  11  title                  77361 non-null  object
#  12  variety                77361 non-null  object
#  13  winery                 77361 non-null  object
# ...

# %%
df.describe().T
# Out:
#               count          mean           std   min      25%      50%  \
# Unnamed: 0  77361.0  38680.000000  22332.341424   0.0  19340.0  38680.0
# points      77361.0     88.435879      3.001784  80.0     86.0     88.0
# price       71903.0     35.172399     38.973739   4.0     17.0     25.0
#
#                 75%      max
# Unnamed: 0  58020.0  77360.0
# points         91.0    100.0
# price          42.0   2500.0

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Unnamed: 0               77361
# country                     41
# description              73592
# designation              27083
# points                      21
# price                      328
# province                   393
# region_1                  1144
# region_2                    17
# taster_name                 19
# taster_twitter_handle       15
# title                    73105
# variety                    625
# winery                   14316
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df['price'].dtype
# Out:
# dtype('float64')

# %%
df['points'].astype('float64')
# Out:
# 0        87.0
# 1        87.0
# 2        87.0
# 3        87.0
# 4        87.0
#          ...
# 77356    87.0
# 77357    87.0
# 77358    87.0
# 77359    87.0
# 77360    87.0
# Name: points, Length: 77361, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     35
# description                  0
# designation              22356
# points                       0
# price                     5458
# province                    35
# region_1                 12607
# region_2                 47620
# taster_name              15817
# taster_twitter_handle    18689
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Unnamed: 0               0.000000
# country                  0.000452
# description              0.000000
# designation              0.288983
# points                   0.000000
# price                    0.070552
# province                 0.000452
# region_1                 0.162963
# region_2                 0.615556
# taster_name              0.204457
# taster_twitter_handle    0.241582
# title                    0.000000
# variety                  0.000000
# winery                   0.000000
# dtype: float64

# %%
df['region_2'].fillna('Unknown')
# Out:
# 0                  Unknown
# 1                  Unknown
# 2        Willamette Valley
# 3                  Unknown
# 4        Willamette Valley
#                ...
# 77356        Central Coast
# 77357              Unknown
# 77358              Unknown
# 77359              Unknown
# 77360              Unknown
# Name: region_2, Length: 77361, dtype: object

# %%
df['taster_twitter_handle'].replace("@kerinokeefe", "@kerino")
# Out:
# 0              @kerino
# 1           @vossroger
# 2          @paulgwine
# 3                  NaN
# 4          @paulgwine
#              ...
# 77356    @mattkettmann
# 77357      @AnneInVino
# 77358          @kerino
# 77359       @vossroger
# 77360       @vossroger
# Name: taster_twitter_handle, Length: 77361, dtype: object

# %%
df['country']
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#            ...
# 77356          US
# 77357      France
# 77358       Italy
# 77359      France
# 77360      France
# Name: country, Length: 77361, dtype: object

# %%
df['country'][0]
# Out:
# 'Italy'

# %%
df['country'][0:5]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
df[['country', 'points']]
# Out:
#         country  points
# 0         Italy      87
# 1      Portugal      87
# 2            US      87
# 3            US      87
# 4            US      87
# ...         ...     ...
# 77356        US      87
# 77357    France      87
# 77358     Italy      87
# 77359    France      87
# 77360    France      87
#
# [77361 rows x 2 columns]

# %%
df[['country', 'points']]['country']
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#            ...
# 77356          US
# 77357      France
# 77358       Italy
# 77359      France
# 77360      France
# Name: country, Length: 77361, dtype: object

# %%
df.loc[:, 'country']
# Out:
# 0           Italy
# 1        Portugal
# 2              US
# 3              US
# 4              US
#            ...
# 77356          US
# 77357      France
# 77358       Italy
# 77359      France
# 77360      France
# Name: country, Length: 77361, dtype: object

# %%
df.loc[1, 'country']
# Out:
# 'Portugal'

# %%
df.loc[1:5, 'country']
# Out:
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# Name: country, dtype: object

# %%
df.loc[[1, 7, 10], 'country']
# Out:
# 1     Portugal
# 7       France
# 10          US
# Name: country, dtype: object

# %%
df.loc[[1, 7, 10], 'country': 'points']
# Out:
#      country                                        description  \
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 7     France  This dry and restrained wine offers spice in p...
# 10        US  Soft, supple plum envelopes an oaky structure ...
#
#        designation  points
# 1         Avidagos      87
# 7              NaN      87
# 10  Mountain Cuvée      87

# %%
df.loc[[1, 7, 10], ['country', 'points']]
# Out:
#      country  points
# 1   Portugal      87
# 7     France      87
# 10        US      87

# %%
df.iloc[1:5, 0]
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Unnamed: 0, dtype: int64

# %%
df.iloc[1:5, 0: 3]
# Out:
#    Unnamed: 0   country                                        description
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...

# %%
df.iloc[1:5, [0, 3]]
# Out:
#    Unnamed: 0                         designation
# 1           1                            Avidagos
# 2           2                                 NaN
# 3           3                Reserve Late Harvest
# 4           4  Vintner's Reserve Wild Child Block

# %%
df.index
# Out:
# RangeIndex(start=0, stop=77361, step=1)

# %%
df.set_index('title')
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# J. Lohr 2015 Gesture Rose of Grenache (Paso Rob...       77356        US
# Jean-Baptiste Adam 2015 Les Natures Gewurztrami...       77357    France
# Cecchi 2013  Rosso di Montalcino                         77358     Italy
# Château de Corcelles 2015  Beaujolais-Villages           77359    France
# Château Gaillard 2015 Vieilles Vignes  (Beaujol...       77360    France
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.set_index('title')
# Out:
#                                                     Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                            0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)                1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                2        US
# St. Julian 2013 Reserve Late Harvest Riesling (...           3        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           4        US
# ...                                                        ...       ...
# J. Lohr 2015 Gesture Rose of Grenache (Paso Rob...       77356        US
# Jean-Baptiste Adam 2015 Les Natures Gewurztrami...       77357    France
# Cecchi 2013  Rosso di Montalcino                         77358     Italy
# Château de Corcelles 2015  Beaujolais-Villages           77359    France
# Château Gaillard 2015 Vieilles Vignes  (Beaujol...       77360    France
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=77361, step=1)

# %%
df.reset_index()
# Out:
#        index  Unnamed: 0   country  \
# 0          0           0     Italy
# 1          1           1  Portugal
# 2          2           2        US
# 3          3           3        US
# 4          4           4        US
# ...      ...         ...       ...
# 77356  77356       77356        US
# 77357  77357       77357    France
# 77358  77358       77358     Italy
# 77359  77359       77359    France
# 77360  77360       77360    France
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 77356  Lightly pink in color with a hint of orange, t...
# 77357  This wine is plump, rounded and rich. Ripe hin...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.reset_index()
# Out:
#        index  Unnamed: 0   country  \
# 0          0           0     Italy
# 1          1           1  Portugal
# 2          2           2        US
# 3          3           3        US
# 4          4           4        US
# ...      ...         ...       ...
# 77356  77356       77356        US
# 77357  77357       77357    France
# 77358  77358       77358     Italy
# 77359  77359       77359    France
# 77360  77360       77360    France
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 77356  Lightly pink in color with a hint of orange, t...
# 77357  This wine is plump, rounded and rich. Ripe hin...
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df['country']=='England'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 77356    False
# 77357    False
# 77358    False
# 77359    False
# 77360    False
# Name: country, Length: 77361, dtype: bool

# %%
df[df['country']=='England']
# Out:
#        Unnamed: 0  country                                        description  \
# 4073         4073  England  A mix of fruity notes immediately hit: white c...
# 6700         6700  England  Crisp green apple flavors are immediately appa...
# 9909         9909  England  Touches of vanilla, cream and lovely hints of ...
# 22156       22156  England  Golden color and hints of oatmeal on the nose ...
# 22369       22369  England  Pure notes of red apple rise from the glass, p...
# 22540       22540  England  An appetizing mix of oatmeal and tart apple fi...
# 24839       24839  England  Very tender notes of baked apple and faint hin...
# 27356       27356  England  Freshly cut peel of tart but ripe red apple en...
# 27364       27364  England  Hints of tart redcurrant have a softenting cre...
# 27848       27848  England  Tart strawberries and cream are spelled out jo...
# 27872       27872  England  Lively, crisp apple notes on the nose immediat...
# ...

# %%
df[df['country']=='England']['country']
# Out:
# 4073     England
# 6700     England
# 9909     England
# 22156    England
# 22369    England
# 22540    England
# 24839    England
# 27356    England
# 27364    England
# 27848    England
# 27872    England
# 31166    England
# 41914    England
# 45533    England
# 45590    England
# 47458    England
# 47460    England
# 47731    England
# 48119    England
# 53623    England
# 53629    England
# 54131    England
# 54133    England
# 54686    England
# 56417    England
# 56611    England
# 56660    England
# 58496    England
# 58747    England
# 58752    England
# 59857    England
# 59863    England
# 60002    England
# 60027    England
# 62352    England
# 62647    England
# 68212    England
# 70570    England
# 70579    England
# 70597    England
# 72070    England
# 72073    England
# 72824    England
# Name: country, dtype: object

# %%
df[df['country']=='England'][['country', 'points']]
# Out:
#        country  points
# 4073   England      90
# 6700   England      91
# 9909   England      95
# 22156  England      91
# 22369  England      94
# 22540  England      89
# 24839  England      90
# 27356  England      93
# 27364  England      92
# 27848  England      92
# 27872  England      91
# 31166  England      90
# 41914  England      89
# 45533  England      90
# 45590  England      94
# 47458  England      89
# 47460  England      89
# 47731  England      91
# 48119  England      89
# 53623  England      89
# 53629  England      89
# 54131  England      93
# 54133  England      93
# 54686  England      92
# 56417  England      91
# 56611  England      90
# 56660  England      91
# 58496  England      92
# 58747  England      91
# 58752  England      91
# 59857  England      92
# 59863  England      92
# 60002  England      95
# 60027  England      95
# 62352  England      90
# 62647  England      90
# 68212  England      90
# 70570  England      94
# 70579  England      94
# ...

# %%
df[(df['country']=='England') & (df['points']>90)]
# Out:
#        Unnamed: 0  country                                        description  \
# 6700         6700  England  Crisp green apple flavors are immediately appa...
# 9909         9909  England  Touches of vanilla, cream and lovely hints of ...
# 22156       22156  England  Golden color and hints of oatmeal on the nose ...
# 22369       22369  England  Pure notes of red apple rise from the glass, p...
# 27356       27356  England  Freshly cut peel of tart but ripe red apple en...
# 27364       27364  England  Hints of tart redcurrant have a softenting cre...
# 27848       27848  England  Tart strawberries and cream are spelled out jo...
# 27872       27872  England  Lively, crisp apple notes on the nose immediat...
# 45590       45590  England  This has the crunchy, enticing freshness of th...
# 47731       47731  England  An abundance of apple flavors—green, golden an...
# 54131       54131  England  Notions of tart redcurrant play on the nose wh...
# ...

# %%
df[(df['country']=='England') & (df['points']>90)][['country', 'points']]
# Out:
#        country  points
# 6700   England      91
# 9909   England      95
# 22156  England      91
# 22369  England      94
# 27356  England      93
# 27364  England      92
# 27848  England      92
# 27872  England      91
# 45590  England      94
# 47731  England      91
# 54131  England      93
# 54133  England      93
# 54686  England      92
# 56417  England      91
# 56660  England      91
# 58496  England      92
# 58747  England      91
# 58752  England      91
# 59857  England      92
# 59863  England      92
# 60002  England      95
# 60027  England      95
# 70570  England      94
# 70579  England      94
# 70597  England      94
# 72070  England      91
# 72073  England      91

# %%
df[(df['country']=='England') | (df['points']>90)]
# Out:
#        Unnamed: 0    country  \
# 119           119     France
# 120           120      Italy
# 121           121         US
# 122           122         US
# 123           123  Australia
# ...           ...        ...
# 77349       77349         US
# 77350       77350         US
# 77351       77351         US
# 77352       77352      Italy
# 77353       77353         US
#
#                                              description  \
# 119    Medium-gold in color. Complex and inviting nos...
# 120    Slightly backward, particularly given the vint...
# 121    The vineyard is one of the better Chardonnay s...
# 122    Defines Rockpile Zinfandel in intensity of fru...
# 123    The blend is roughly two-thirds Shiraz and one...
# ...                                                  ...
# 77349  This wine is 73% Cabernet Sauvignon and a whop...
# 77350  A rare single-vineyard bottling from this tiny...
# 77351  This wine is a blend of top sites Stoney Vine,...
# ...

# %%
df[df['country'].isin(['England', 'Ukraine'])]
# Out:
#        Unnamed: 0  country                                        description  \
# 4073         4073  England  A mix of fruity notes immediately hit: white c...
# 6700         6700  England  Crisp green apple flavors are immediately appa...
# 9909         9909  England  Touches of vanilla, cream and lovely hints of ...
# 19530       19530  Ukraine  On the nose, this nonvintage sparkler from the...
# 22156       22156  England  Golden color and hints of oatmeal on the nose ...
# 22369       22369  England  Pure notes of red apple rise from the glass, p...
# 22540       22540  England  An appetizing mix of oatmeal and tart apple fi...
# 24839       24839  England  Very tender notes of baked apple and faint hin...
# 27356       27356  England  Freshly cut peel of tart but ripe red apple en...
# 27364       27364  England  Hints of tart redcurrant have a softenting cre...
# 27848       27848  England  Tart strawberries and cream are spelled out jo...
# ...

# %%
df[df['province'].isnull()]
# Out:
#        Unnamed: 0 country                                        description  \
# 913           913     NaN  Amber in color, this wine has aromas of peach ...
# 3131         3131     NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243         4243     NaN  Violet-red in color, this semisweet wine has a...
# 9509         9509     NaN  This mouthwatering blend starts with a nose of...
# 9750         9750     NaN  This orange-style wine has a cloudy yellow-gol...
# 11150       11150     NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 11348       11348     NaN  Light and fruity, this is a wine that has some...
# 14030       14030     NaN  This Furmint, grown in marl soils, has aromas ...
# 16000       16000     NaN  Jumpy, jammy aromas of foxy black fruits are s...
# 16749       16749     NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 18075       18075     NaN  Delicate white flowers and a spin of lemon pee...
# ...

# %%
df[df['province'].notnull()]
# Out:
#        Unnamed: 0   country  \
# 0               0     Italy
# 1               1  Portugal
# 2               2        US
# 3               3        US
# 4               4        US
# ...           ...       ...
# 77356       77356        US
# 77357       77357    France
# 77358       77358     Italy
# 77359       77359    France
# 77360       77360    France
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 77356  Lightly pink in color with a hint of orange, t...
# 77357  This wine is plump, rounded and rich. Ripe hin...
# 77358  Underbrush, red berry and coffee bean lead the...
# ...

# %%
df.describe(include=['object']).T
# Out:
#                        count unique  \
# country                77326     41
# description            77361  73592
# designation            55005  27083
# province               77326    393
# region_1               64754   1144
# region_2               29741     17
# taster_name            61544     19
# taster_twitter_handle  58672     15
# title                  77361  73105
# variety                77361    625
# winery                 77361  14316
#
#                                                                      top  \
# country                                                               US
# description            Stalky aromas suggest hay and green herbs, wit...
# designation                                                      Reserve
# province                                                      California
# region_1                                                     Napa Valley
# region_2                                                   Central Coast
# ...

# %%
print(df['points'].mean())
# Out:
# 88.43587854345213

# %%
df['taster_name']
# Out:
# 0             Kerin O’Keefe
# 1                Roger Voss
# 2              Paul Gregutt
# 3        Alexander Peartree
# 4              Paul Gregutt
#                 ...
# 77356         Matt Kettmann
# 77357      Anne Krebiehl MW
# 77358         Kerin O’Keefe
# 77359            Roger Voss
# 77360            Roger Voss
# Name: taster_name, Length: 77361, dtype: object

# %%
df['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
df['taster_name'].nunique()
# Out:
# 19

# %%
df['taster_name'].value_counts()
# Out:
# Roger Voss            15440
# Michael Schachner      9045
# Kerin O’Keefe          6432
# Paul Gregutt           5758
# Virginie Boone         5546
# Matt Kettmann          3665
# Joe Czerwinski         3058
# Sean P. Sullivan       2795
# Anna Lee C. Iijima     2555
# Jim Gordon             2438
# Anne Krebiehl MW       2101
# Lauren Buzzeo          1116
# Susan Kostrzewa         681
# Jeff Jenssen            292
# Mike DeSimone           286
# Alexander Peartree      256
# Carrie Dykes             61
# Fiona Adams              14
# Christina Pickard         5
# Name: taster_name, dtype: int64

# %%
df['taster_name'].value_counts(normalize=True)
# Out:
# Roger Voss            0.250877
# Michael Schachner     0.146968
# Kerin O’Keefe         0.104511
# Paul Gregutt          0.093559
# Virginie Boone        0.090114
# Matt Kettmann         0.059551
# Joe Czerwinski        0.049688
# Sean P. Sullivan      0.045415
# Anna Lee C. Iijima    0.041515
# Jim Gordon            0.039614
# Anne Krebiehl MW      0.034138
# Lauren Buzzeo         0.018133
# Susan Kostrzewa       0.011065
# Jeff Jenssen          0.004745
# Mike DeSimone         0.004647
# Alexander Peartree    0.004160
# Carrie Dykes          0.000991
# Fiona Adams           0.000227
# Christina Pickard     0.000081
# Name: taster_name, dtype: float64

# %%
points_mean=df['points'].mean()

print(points_mean)
# Out:
# 88.43587854345213

# %%
df['points'].map(lambda row: row-points_mean)
# Out:
# 0       -1.435879
# 1       -1.435879
# 2       -1.435879
# 3       -1.435879
# 4       -1.435879
#            ...
# 77356   -1.435879
# 77357   -1.435879
# 77358   -1.435879
# 77359   -1.435879
# 77360   -1.435879
# Name: points, Length: 77361, dtype: float64

# %%
df.groupby('points')['price'].mean()
# Out:
# points
# 80      15.765060
# 81      17.741176
# 82      18.746300
# 83      18.284467
# 84      19.251255
# 85      20.132308
# 86      22.129271
# 87      25.023664
# 88      28.558152
# 89      32.126557
# 90      36.843064
# 91      42.895021
# 92      51.147338
# 93      63.738784
# 94      80.952180
# 95     112.057796
# 96     161.047970
# 97     229.691489
# 98     288.950000
# 99     325.600000
# 100    328.625000
# Name: price, dtype: float64

# %%
df.groupby('points')['price'].agg(['max', 'min'])
# Out:
#            max    min
# points
# 80        55.0    5.0
# 81       130.0    5.0
# 82       150.0    5.0
# 83       225.0    4.0
# 84       225.0    4.0
# 85       200.0    4.0
# 86       170.0    4.0
# 87       325.0    5.0
# 88       325.0    6.0
# 89       500.0    7.0
# 90       510.0    8.0
# 91       780.0    7.0
# 92       750.0   11.0
# 93       580.0   12.0
# 94      1000.0   13.0
# 95       775.0   20.0
# 96      2500.0   27.0
# 97      2000.0   40.0
# 98      1900.0   50.0
# 99       850.0   75.0
# 100      550.0  150.0

# %%
df.groupby('points')['price'].agg(['max', min])
# Out:
#            max    min
# points
# 80        55.0    5.0
# 81       130.0    5.0
# 82       150.0    5.0
# 83       225.0    4.0
# 84       225.0    4.0
# 85       200.0    4.0
# 86       170.0    4.0
# 87       325.0    5.0
# 88       325.0    6.0
# 89       500.0    7.0
# 90       510.0    8.0
# 91       780.0    7.0
# 92       750.0   11.0
# 93       580.0   12.0
# 94      1000.0   13.0
# 95       775.0   20.0
# 96      2500.0   27.0
# 97      2000.0   40.0
# 98      1900.0   50.0
# 99       850.0   75.0
# 100      550.0  150.0

# %%
df.sort_values('price')
# Out:
#        Unnamed: 0       country  \
# 29553       29553     Argentina
# 64590       64590            US
# 61768       61768         Spain
# 31530       31530            US
# 1987         1987         Spain
# ...           ...           ...
# 77234       77234  South Africa
# 77235       77235  South Africa
# 77293       77293        France
# 77319       77319        France
# 77325       77325            US
#
#                                              description  \
# 29553  Crimson in color but also translucent, with a ...
# 64590  There's a lot going on in this Merlot, which i...
# 61768  This opens with standard cherry and berry arom...
# 31530  Packaged in a cute yellow recyclable Tetrapak,...
# 1987   Berry and cherry aromas are surprisingly sturd...
# ...                                                  ...
# 77234  Winemaker: Andrea Mullineux. Named Trifecta fo...
# 77235  Winemaker: Louis Strydom. This Cabernet Sauvig...
# ...

# %%
df.sort_values('price', ascending=True)
# Out:
#        Unnamed: 0       country  \
# 29553       29553     Argentina
# 64590       64590            US
# 61768       61768         Spain
# 31530       31530            US
# 1987         1987         Spain
# ...           ...           ...
# 77234       77234  South Africa
# 77235       77235  South Africa
# 77293       77293        France
# 77319       77319        France
# 77325       77325            US
#
#                                              description  \
# 29553  Crimson in color but also translucent, with a ...
# 64590  There's a lot going on in this Merlot, which i...
# 61768  This opens with standard cherry and berry arom...
# 31530  Packaged in a cute yellow recyclable Tetrapak,...
# 1987   Berry and cherry aromas are surprisingly sturd...
# ...                                                  ...
# 77234  Winemaker: Andrea Mullineux. Named Trifecta fo...
# 77235  Winemaker: Louis Strydom. This Cabernet Sauvig...
# ...

# %%
df.sort_values('price', ascending=False)
# Out:
#        Unnamed: 0       country  \
# 15840       15840        France
# 65352       65352        France
# 1558         1558        France
# 1575         1575        France
# 1571         1571        France
# ...           ...           ...
# 77234       77234  South Africa
# 77235       77235  South Africa
# 77293       77293        France
# 77319       77319        France
# 77325       77325            US
#
#                                              description  \
# 15840  The wine is a velvet glove in an iron fist. Th...
# 65352  This extravagantly perfumed wine has great jui...
# 1558   A massive wine for Margaux, packed with tannin...
# 1575   The purest Cabernet Sauvignon fruit, with dark...
# 1571   Solid, very structured, packed with dense and ...
# ...                                                  ...
# 77234  Winemaker: Andrea Mullineux. Named Trifecta fo...
# 77235  Winemaker: Louis Strydom. This Cabernet Sauvig...
# ...

# %%
df.sort_values(['price', 'country'], ascending=[False, False])
# Out:
#        Unnamed: 0    country  \
# 15840       15840     France
# 65352       65352     France
# 1558         1558     France
# 1575         1575     France
# 1571         1571     France
# ...           ...        ...
# 74805       74805  Argentina
# 3131         3131        NaN
# 11348       11348        NaN
# 16749       16749        NaN
# 57612       57612        NaN
#
#                                              description  \
# 15840  The wine is a velvet glove in an iron fist. Th...
# 65352  This extravagantly perfumed wine has great jui...
# 1558   A massive wine for Margaux, packed with tannin...
# 1575   The purest Cabernet Sauvignon fruit, with dark...
# 1571   Solid, very structured, packed with dense and ...
# ...                                                  ...
# 74805  Sharp and tight on the nose, and then it stays...
# 3131   Soft, fruity and juicy, this is a pleasant, si...
# 11348  Light and fruity, this is a wine that has some...
# ...
